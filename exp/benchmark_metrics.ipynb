# %%
from sklearn.metrics import f1_score, precision_score, recall_score
import pandas as pd

# %%
df = pd.read_csv("../beql_result.csv")
df.head(2)
# Out:
#                             id  \
# 0  Dummit-Foote|exercise_9_4_9
# 1      Putnam|exercise_1998_b6
#
#                                         nl_statement  \
# 0  Prove that the polynomial $x^{2}-\sqrt{2}$ is ...
# 1  Prove that, for any integers $a, b, c$, there ...
#
#                                     lean4_src_header  \
# 0  import Mathlib\n\nopen Fintype Subgroup Set Po...
# 1     import Mathlib\n\nopen scoped BigOperators\n\n
#
#                                  lean4_formalization  \
# 0  theorem exercise_9_4_9 :\n  Irreducible (X^2 -...
# 1  theorem exercise_1998_b6 (a b c : ℤ) :\n  ∃ n ...
#
#                                     lean4_prediction  correct   beql
# 0  theorem dummy (F : Type*) [Field F] {p : F[X]}...    False  False
# 1  theorem dummy (a b c : ℤ) : ∃ (n : ℕ) (H : 0 <...    False  False

# %%
df.shape
# Out:
# (1452, 7)

# %%
y_true = df["correct"]
y_pred = df["beql"]

print(f"f1 score: {f1_score(y_true, y_pred):.2f}")
print(f"precision score: {precision_score(y_true, y_pred):.2f}")
print(f"recall score: {recall_score(y_true, y_pred):.2f}")
# Out:
# f1 score: 0.49
# precision score: 1.00
# recall score: 0.32
